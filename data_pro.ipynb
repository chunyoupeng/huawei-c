# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('3-merged.xlsx')
df
# Out:
#        温度           磁芯损耗  材料  励磁波形
# 0      25    1997.955250   1     1
# 1      25    2427.749830   1     1
# 2      25    3332.725760   1     1
# 3      25    4502.908007   1     1
# 4      25    6063.023248   1     1
# ...    ..            ...  ..   ...
# 12395  90   20604.900210   4     3
# 12396  90   26504.284280   4     3
# 12397  90   46232.491530   4     3
# 12398  90   61458.085900   4     3
# 12399  90  107581.189300   4     3
#
# [12400 rows x 4 columns]

# %%
import pandas as pd

# 假设你的数据框是 df
# 读取数据（这里你需要根据实际情况调整）
# df = pd.read_csv('your_data.csv')  # 如果是从CSV文件读取

# 计算均值
mean_values = df.groupby(['温度', '材料', '励磁波形']).mean()

# 如果你想要查看均值数据
print(mean_values)
# Out:
#                      磁芯损耗
# 温度 材料 励磁波形
# 25 1  1     133503.357368
#       2     278741.217508
#       3     253270.300241
#    2  1     111256.320903
#       2     415553.840471
#       3     355257.736919
#    3  1     128955.306032
#       2     387235.459554
#       3     419505.993679
#    4  1      48728.833809
#       2     153636.266026
#       3     229097.555789
# 50 1  1     101899.677119
#       2     234925.958082
#       3     197642.723830
#    2  1     104904.666328
#       2     328612.662737
#       3     307549.738086
#    3  1     103356.247232
#       2     336952.482209
#       3     353424.047573
#    4  1      46663.650828
#       2     130724.679342
#       3     144309.808377
# 70 1  1      88388.417255
#       2     197093.491846
#       3     169289.498584
#    2  1      80530.463067
#       2     293533.754536
#       3     249337.240836
#    3  1      74524.828080
#       2     305269.926358
#       3     323474.823643
#    4  1      40432.670824
# ...

# %%
mean_values.to_csv('问题3_损失均值.csv', encoding='utf-8', index=False)
